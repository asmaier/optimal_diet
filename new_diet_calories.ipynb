# %%
import pandas as pd

from ortools.linear_solver import pywraplp
from ortools.init import pywrapinit

# %%
df_nutrients = pd.read_csv("rdi.csv")

# %%
df_nutrients
# Out:
#    Energy (kcal/d)  Protein (g/d)  Carbohydrate (g/d)  Fat (g/d)  \
# 0             2500           96.0              281.25  97.222222
#
#    Fibres (g/d)   LA (g/d)  ALA (g/d)  EPA (g/d)  DHA (g/d)  Calcium (mg/d)  \
# 0          30.0  11.111111   1.388889      0.125      0.125          1000.0
#
#    ...  Vitamin K1 (µg/d)  Vitamin C (mg/d)  Vitamin B1 or Thiamin (mg/d)  \
# 0  ...               70.0             110.0                        1.0467
#
#    Vitamin B2 or Riboflavin (mg/d)  Vitamin B3 or Niacin (mg/d)  \
# 0                              1.6                      16.7472
#
#    Vitamin B5 or Pantothenic acid (mg/d)  Vitamin B6 (mg/d)  \
# 0                                    5.0                1.7
#
#    Vitamin B9 or Folate (µg/d)  Vitamin B12 (µg/d)  Vitamin A (µg/d)
# 0                        330.0                 4.0             750.0
#
# [1 rows x 33 columns]

# %%
nutrients = [(key,value) for key,value in df_nutrients.to_dict("records")[0].items()]
nutrients
# Out:
# [('Energy (kcal/d)', 2500),
#  ('Protein (g/d)', 96.0),
#  ('Carbohydrate (g/d)', 281.25),
#  ('Fat (g/d)', 97.22222222222224),
#  ('Fibres (g/d)', 30.0),
#  ('LA (g/d)', 11.11111111111111),
#  ('ALA (g/d)', 1.3888888888888888),
#  ('EPA (g/d)', 0.125),
#  ('DHA (g/d)', 0.125),
#  ('Calcium (mg/d)', 1000.0),
#  ('Chloride (mg/d)', 3100.0),
#  ('Copper (mg/d)', 1.6),
#  ('Iron (mg/d)', 11.0),
#  ('Iodine (µg/d)', 150.0),
#  ('Magnesium (mg/d)', 350.0),
#  ('Manganese (mg/d)', 3.0),
#  ('Phosphorus (mg/d)', 550.0),
#  ('Potassium (mg/d)', 3500.0),
#  ('Selenium (µg/d)', 70.0),
#  ('Sodium (mg/d)', 2000.0),
#  ('Zinc (mg/d)', 10.0),
#  ('Vitamin D (µg/d)', 15.0),
#  ('Vitamin E (mg/d)', 13.0),
#  ('Vitamin K1 (µg/d)', 70.0),
#  ('Vitamin C (mg/d)', 110.0),
#  ('Vitamin B1 or Thiamin (mg/d)', 1.0467000000000002),
#  ('Vitamin B2 or Riboflavin (mg/d)', 1.6),
#  ('Vitamin B3 or Niacin (mg/d)', 16.747200000000003),
#  ('Vitamin B5 or Pantothenic acid (mg/d)', 5.0),
#  ('Vitamin B6 (mg/d)', 1.7),
#  ('Vitamin B9 or Folate (µg/d)', 330.0),
#  ('Vitamin B12 (µg/d)', 4.0),
#  ('Vitamin A (µg/d)', 750.0)]

# %%
df_foods=pd.read_csv("ciqual_2020.csv")

# %%
# https://stackoverflow.com/questions/18172851/deleting-dataframe-row-in-pandas-based-on-column-value
def filter_rows_by_values(df, col, values):
    return df[~df[col].isin(values)]

# %%
# remove certain foods

remove_foods = ["Acerola. pulp. raw. sampled in the island of La Martiniqu", 
                "Egg. powd", "Milk. powder. semi-skimmed", 
                "Decaffeinated coffee. powder. instan",
                "Decaffeinated not instant coffee. without sugar. ready-to-drink",
                "Espresso coffee. not instant coffee. without sugar. ready-to-drink",
                "Not instant coffee. without sugar. ready-to-drink",
                "Tea. brewed. without sug",
                "Royal jelly", 
                "Cocoa powder for baby beverag", 
                "Egg white. powd", 
                "Milk. powder. skimmed", 
                "Instant cereal (powder to be reconstituted) for baby from 4/6 month",
                "Milk. powder. whol",
                "Instant cereal (powder to be reconstituted) for baby from 6 month",
                "Egg yolk. powd", 
                "Gelatine. dried", 
                "Baby milk. first age. powd",
                "Baby milk. second age. powd",
                "Soya flou", 
                "Sea belt (Saccharina latissima). dried or dehydrated", 
                "Veal stock for sauce and cooking. dehydrated", 
                "Broth. stock or bouillon. meat and vegetables. with fat. dehydrated", 
                "Broth. stock or bouillon. meat and vegetables. defatted. dehydrated",
                "Broth. stock or bouillon. beef. dehydrated",
                "Madeira wine aspic. dehydrated", 
                "Nutritional y", 
                "Chewing gum. without sug", 
                "Chewing gum. sugar level unknown (average)",
                "Baking powder or raising agen", "Prepared mixed meat/fish canned. salad", "Stevia sweeten"]

df_foods_filtered = filter_rows_by_values(df_foods, "Name", remove_foods)

# %%
commodities = list(df_foods_filtered["Name"])

# %%
data = df_foods_filtered.drop("Name", axis=1).values.tolist()

# %%
## trying to optimize for calories here.
solver2 = pywraplp.Solver.CreateSolver('GLOP')

# %%
# remove foods with no calories
df_foods_filtered2 = df_foods_filtered[df_foods_filtered["Energy (kcal/100g)"] > 0.0]
commodities = list(df_foods_filtered2["Name"])
data = df_foods_filtered2.drop("Name", axis=1).values.tolist()

# %%
# Declare an array to hold our variables. 
foods = [solver2.NumVar(0.0, solver2.infinity(), item) for item in commodities]

print('Number of variables =', solver2.NumVariables())
# Out:
# Number of variables = 2173

# %%
nutrients[0] = ("Energy (kcal/d)", 0.0)

# %%
# Create the constraints, one per nutrient. (data = nutrients_per_100_gramm)
# gurobipy can express a lists or arrays of constraints with a nicer DSL 
# instead of the many loops necessary with OR-Tools
constraints = []
for i, nutrient in enumerate(nutrients):
    constraints.append(solver2.Constraint(nutrient[1], solver2.infinity(), nutrient[0]))
    for j, item in enumerate(data):
        constraints[i].SetCoefficient(foods[j], item[i])

print('Number of constraints =', solver2.NumConstraints())
# Out:
# Number of constraints = 33

# %%
# Objective function: Minimize the sum of (price-normalized) foods.
objective = solver2.Objective()
for i, food in enumerate(foods):
    objective.SetCoefficient(food, data[i][0])
objective.SetMinimization()

# %%
status = solver2.Solve()

# Check that the problem has an optimal solution.
if status != solver2.OPTIMAL:
    print('The problem does not have an optimal solution!')
    if status == solver2.FEASIBLE:
        print('A potentially suboptimal solution was found.')
    else:
        print('The solver could not solve the problem.')
        exit(1)

# %%
# Display the amounts (in dollars) to purchase of each food.
nutrients_result = [0] * len(nutrients)
print('\nDaily Foods:')
for i, food in enumerate(foods):
    if food.solution_value() > 0.0:
        print('{}: {} kcal {} gr'.format(commodities[i], food.solution_value()*data[i][0], food.solution_value() * 100))
        for j, _ in enumerate(nutrients):
            nutrients_result[j] += data[i][j] * food.solution_value()
print('\nOptimal daily calories: {:.4f} kcal'.format(objective.Value()))
# Out:
# Daily Foods:
# Miso soup. dehydrated. reconstituted: 19.99303403262975 kcal 116.91832767619736 gr
# Lamb's lettuce. raw: 76.89731063637171 kcal 457.7220871212602 gr
# Spinach. young leaves. raw: 6.1621568728518294 kcal 33.6729883762395 gr
# Gnocchi. cooked (average): 1458.5833836749262 kcal 805.8471733010641 gr
# Liver. calf. cooked: 2.0213716192299107 kcal 1.6705550572148022 gr
# Liver. turkey. raw: 85.07801636344372 kcal 69.1691189946697 gr
# Dry-cured ham. fat and rind removed: 97.6604030115378 kcal 50.86479323517593 gr
# Horse mackerel. oily (autumn. winter). raw: 29.456018868913574 kcal 20.038108074090864 gr
# Anchovy. fillets. in oil. semi-preserved. drained: 7.759482582810963 kcal 4.263451968577452 gr
# Wheat germ oil: 53.57467876464684 kcal 5.95274208496076 gr
# Walnut oil: 58.05456190581198 kcal 6.450506878423553 gr
# Grapeseed oil: 52.6841448375099 kcal 5.8537938708344335 gr
# Cod liver oil: 13.855678715251205 kcal 1.5395198572501338 gr
# Parsley. fresh: 19.125079850924273 kcal 44.4769298858704 gr
# Sea lettuce (ulva sp.). dried or dehydrated): 4.376312479833253 kcal 2.124423533899637 gr
# Gracilaria seaweeds (Gracilaria verrucosa). dried or dehydrated: 0.7955405747812704 kcal 0.3273829525848849 gr
#
# Optimal daily calories: 1986.0772 kcal

# %%
print('\nNutrients per day:')
for i, nutrient in enumerate(nutrients):
    print('{}: {:.2f} (min {})'.format(nutrient[0], nutrients_result[i],
                                       nutrient[1]))
# Out:
# Nutrients per day:
# Energy (kcal/d): 1986.08 (min 0.0)
# Protein (g/d): 96.00 (min 96.0)
# Carbohydrate (g/d): 281.25 (min 281.25)
# Fat (g/d): 97.22 (min 97.22222222222224)
# Fibres (g/d): 30.00 (min 30.0)
# LA (g/d): 11.11 (min 11.11111111111111)
# ALA (g/d): 1.39 (min 1.3888888888888888)
# EPA (g/d): 0.27 (min 0.125)
# DHA (g/d): 0.43 (min 0.125)
# Calcium (mg/d): 1149.88 (min 1000.0)
# Chloride (mg/d): 3100.00 (min 3100.0)
# Copper (mg/d): 1.60 (min 1.6)
# Iron (mg/d): 19.80 (min 11.0)
# Iodine (µg/d): 2021.79 (min 150.0)
# Magnesium (mg/d): 350.00 (min 350.0)
# Manganese (mg/d): 3.00 (min 3.0)
# Phosphorus (mg/d): 567.60 (min 550.0)
# Potassium (mg/d): 3608.33 (min 3500.0)
# Selenium (µg/d): 133.14 (min 70.0)
# Sodium (mg/d): 5311.28 (min 2000.0)
# Zinc (mg/d): 10.40 (min 10.0)
# Vitamin D (µg/d): 15.00 (min 15.0)
# Vitamin E (mg/d): 13.00 (min 13.0)
# Vitamin K1 (µg/d): 807.25 (min 70.0)
# Vitamin C (mg/d): 110.00 (min 110.0)
# Vitamin B1 or Thiamin (mg/d): 1.05 (min 1.0467000000000002)
# Vitamin B2 or Riboflavin (mg/d): 2.20 (min 1.6)
# Vitamin B3 or Niacin (mg/d): 16.75 (min 16.747200000000003)
# Vitamin B5 or Pantothenic acid (mg/d): 5.91 (min 5.0)
# Vitamin B6 (mg/d): 1.70 (min 1.7)
# Vitamin B9 or Folate (µg/d): 793.53 (min 330.0)
# Vitamin B12 (µg/d): 19.67 (min 4.0)
# Vitamin A (µg/d): 9255.63 (min 750.0)

# %%
# Nutrient are far from optimal: Too much Vitamin A, too much Iodine, too much sodium
# It seems to be much better to optimize for weight instead of optimizing for calories

# %%
pd.set_option('display.max_columns', 500)

nutrient_per_food = {}

for i, food in enumerate(foods):
    if food.solution_value() > 0.0:      
        for j, nutrient in enumerate(nutrients):
            if food in nutrient_per_food:
                nutrient_per_food[food].append(data[i][j] * food.solution_value())
            else:
                nutrient_per_food[food]=[data[i][j] * food.solution_value()]
                
foods_df = pd.DataFrame.from_dict(nutrient_per_food, orient='index', columns=[n[0] for n in nutrients])

for i, nutrient in enumerate(nutrients):
    foods_df[nutrient[0]]=(foods_df[nutrient[0]]/nutrients_result[i]*100).round(2)

display(foods_df)
# Out:
#                                                     Energy (kcal/d)  \
# Miso soup. dehydrated. reconstituted                           1.01
# Lamb's lettuce. raw                                            3.87
# Spinach. young leaves. raw                                     0.31
# Gnocchi. cooked (average)                                     73.44
# Liver. calf. cooked                                            0.10
# Liver. turkey. raw                                             4.28
# Dry-cured ham. fat and rind removed                            4.92
# Horse mackerel. oily (autumn. winter). raw                     1.48
# Anchovy. fillets. in oil. semi-preserved. drained              0.39
# Wheat germ oil                                                 2.70
# Walnut oil                                                     2.92
# Grapeseed oil                                                  2.65
# Cod liver oil                                                  0.70
# Parsley. fresh                                                 0.96
# Sea lettuce (ulva sp.). dried or dehydrated)                   0.22
# Gracilaria seaweeds (Gracilaria verrucosa). dri...             0.04
#
#                                                     Protein (g/d)  \
# Miso soup. dehydrated. reconstituted                         1.68
# Lamb's lettuce. raw                                          9.54
# Spinach. young leaves. raw                                   0.72
# Gnocchi. cooked (average)                                   53.22
# Liver. calf. cooked                                          0.33
# Liver. turkey. raw                                          13.19
# Dry-cured ham. fat and rind removed                         13.93
# Horse mackerel. oily (autumn. winter). raw                   4.09
# Anchovy. fillets. in oil. semi-preserved. drained            1.17
# Wheat germ oil                                               0.00
# Walnut oil                                                   0.00
# Grapeseed oil                                                0.00
# Cod liver oil                                                0.00
# Parsley. fresh                                               1.72
# Sea lettuce (ulva sp.). dried or dehydrated)                 0.35
# Gracilaria seaweeds (Gracilaria verrucosa). dri...           0.06
#
#                                                     Carbohydrate (g/d)  \
# Miso soup. dehydrated. reconstituted                              0.91
# Lamb's lettuce. raw                                               0.81
# Spinach. young leaves. raw                                        0.10
# Gnocchi. cooked (average)                                        97.42
# Liver. calf. cooked                                               0.03
# Liver. turkey. raw                                                0.00
# Dry-cured ham. fat and rind removed                               0.05
# Horse mackerel. oily (autumn. winter). raw                        0.00
# Anchovy. fillets. in oil. semi-preserved. drained                 0.00
# Wheat germ oil                                                    0.00
# Walnut oil                                                        0.00
# Grapeseed oil                                                     0.00
# Cod liver oil                                                     0.00
# Parsley. fresh                                                    0.55
# Sea lettuce (ulva sp.). dried or dehydrated)                      0.10
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                0.02
#
#                                                     Fat (g/d)  Fibres (g/d)  \
# Miso soup. dehydrated. reconstituted                     0.60          1.95
# Lamb's lettuce. raw                                      2.35         35.09
# Spinach. young leaves. raw                               0.14          2.69
# Gnocchi. cooked (average)                               65.32         51.04
# Liver. calf. cooked                                      0.05          0.00
# Liver. turkey. raw                                       3.91          0.00
# Dry-cured ham. fat and rind removed                      4.97          0.00
# Horse mackerel. oily (autumn. winter). raw               1.58          0.00
# Anchovy. fillets. in oil. semi-preserved. drained        0.37          0.04
# Wheat germ oil                                           6.12          0.00
# Walnut oil                                               6.63          0.00
# Grapeseed oil                                            6.02          0.00
# Cod liver oil                                            1.58          0.00
# Parsley. fresh                                           0.29          6.38
# Sea lettuce (ulva sp.). dried or dehydrated)             0.04          2.44
# Gracilaria seaweeds (Gracilaria verrucosa). dri...       0.01          0.38
#
#                                                     LA (g/d)  ALA (g/d)  \
# Miso soup. dehydrated. reconstituted                    0.10       0.82
# Lamb's lettuce. raw                                     0.41       3.30
# Spinach. young leaves. raw                              0.12       4.12
# Gnocchi. cooked (average)                               0.00       0.00
# Liver. calf. cooked                                     0.10       0.04
# Liver. turkey. raw                                      6.97       1.89
# Dry-cured ham. fat and rind removed                     0.00       0.00
# Horse mackerel. oily (autumn. winter). raw              0.13       0.61
# Anchovy. fillets. in oil. semi-preserved. drained       0.13       0.16
# Wheat germ oil                                         25.13      25.33
# Walnut oil                                             32.57      55.27
# Grapeseed oil                                          33.56       1.35
# Cod liver oil                                           0.38       1.98
# Parsley. fresh                                          0.40       5.12
# Sea lettuce (ulva sp.). dried or dehydrated)            0.00       0.00
# Gracilaria seaweeds (Gracilaria verrucosa). dri...      0.00       0.00
#
#                                                     EPA (g/d)  DHA (g/d)  \
# Miso soup. dehydrated. reconstituted                     4.21       2.65
# Lamb's lettuce. raw                                     16.82      10.58
# Spinach. young leaves. raw                               1.24       0.78
# Gnocchi. cooked (average)                                0.00       0.00
# Liver. calf. cooked                                      0.00       0.00
# Liver. turkey. raw                                       2.29       7.19
# Dry-cured ham. fat and rind removed                      0.00       0.00
# Horse mackerel. oily (autumn. winter). raw              21.35      32.41
# Anchovy. fillets. in oil. semi-preserved. drained        6.42       5.71
# Wheat germ oil                                           0.00       0.00
# Walnut oil                                               0.00       0.00
# Grapeseed oil                                            0.22       0.14
# Cod liver oil                                           47.46      40.55
# Parsley. fresh                                           0.00       0.00
# Sea lettuce (ulva sp.). dried or dehydrated)             0.00       0.00
# Gracilaria seaweeds (Gracilaria verrucosa). dri...       0.00       0.00
#
#                                                     Calcium (mg/d)  \
# Miso soup. dehydrated. reconstituted                          1.83
# Lamb's lettuce. raw                                          16.32
# Spinach. young leaves. raw                                    3.22
# Gnocchi. cooked (average)                                    65.60
# Liver. calf. cooked                                           0.01
# Liver. turkey. raw                                            1.20
# Dry-cured ham. fat and rind removed                           0.00
# Horse mackerel. oily (autumn. winter). raw                    0.10
# Anchovy. fillets. in oil. semi-preserved. drained             0.70
# Wheat germ oil                                                0.00
# Walnut oil                                                    0.00
# Grapeseed oil                                                 0.00
# Cod liver oil                                                 0.00
# Parsley. fresh                                                8.43
# Sea lettuce (ulva sp.). dried or dehydrated)                  2.22
# Gracilaria seaweeds (Gracilaria verrucosa). dri...            0.37
#
#                                                     Chloride (mg/d)  \
# Miso soup. dehydrated. reconstituted                          24.93
# Lamb's lettuce. raw                                            6.70
# Spinach. young leaves. raw                                     0.76
# Gnocchi. cooked (average)                                      0.00
# Liver. calf. cooked                                            0.00
# Liver. turkey. raw                                             0.00
# Dry-cured ham. fat and rind removed                           53.82
# Horse mackerel. oily (autumn. winter). raw                     0.00
# Anchovy. fillets. in oil. semi-preserved. drained              8.38
# Wheat germ oil                                                 0.00
# Walnut oil                                                     0.00
# Grapeseed oil                                                  0.19
# Cod liver oil                                                  0.00
# Parsley. fresh                                                 5.22
# Sea lettuce (ulva sp.). dried or dehydrated)                   0.00
# Gracilaria seaweeds (Gracilaria verrucosa). dri...             0.00
#
#                                                     Copper (mg/d)  \
# Miso soup. dehydrated. reconstituted                         4.38
# Lamb's lettuce. raw                                         28.61
# Spinach. young leaves. raw                                   1.68
# Gnocchi. cooked (average)                                    0.00
# Liver. calf. cooked                                         20.99
# Liver. turkey. raw                                          37.18
# Dry-cured ham. fat and rind removed                          0.00
# Horse mackerel. oily (autumn. winter). raw                   1.25
# Anchovy. fillets. in oil. semi-preserved. drained            0.67
# Wheat germ oil                                               0.00
# Walnut oil                                                   0.00
# Grapeseed oil                                                0.07
# Cod liver oil                                                0.01
# Parsley. fresh                                               3.34
# Sea lettuce (ulva sp.). dried or dehydrated)                 1.74
# Gracilaria seaweeds (Gracilaria verrucosa). dri...           0.09
#
#                                                     Iron (mg/d)  \
# Miso soup. dehydrated. reconstituted                       1.12
# Lamb's lettuce. raw                                        9.25
# Spinach. young leaves. raw                                 3.06
# Gnocchi. cooked (average)                                 30.52
# Liver. calf. cooked                                        0.38
# Liver. turkey. raw                                        31.23
# Dry-cured ham. fat and rind removed                        3.60
# Horse mackerel. oily (autumn. winter). raw                 0.86
# Anchovy. fillets. in oil. semi-preserved. drained          0.69
# Wheat germ oil                                             0.00
# Walnut oil                                                 0.00
# Grapeseed oil                                              0.01
# Cod liver oil                                              0.01
# Parsley. fresh                                            10.49
# Sea lettuce (ulva sp.). dried or dehydrated)               8.46
# Gracilaria seaweeds (Gracilaria verrucosa). dri...         0.33
#
#                                                     Iodine (µg/d)  \
# Miso soup. dehydrated. reconstituted                         4.05
# Lamb's lettuce. raw                                          4.53
# Spinach. young leaves. raw                                   1.00
# Gnocchi. cooked (average)                                    0.00
# Liver. calf. cooked                                          0.00
# Liver. turkey. raw                                           0.00
# Dry-cured ham. fat and rind removed                          0.03
# Horse mackerel. oily (autumn. winter). raw                   0.21
# Anchovy. fillets. in oil. semi-preserved. drained            0.06
# Wheat germ oil                                               0.00
# Walnut oil                                                   0.00
# Grapeseed oil                                                0.06
# Cod liver oil                                                0.30
# Parsley. fresh                                               0.11
# Sea lettuce (ulva sp.). dried or dehydrated)                 9.66
# Gracilaria seaweeds (Gracilaria verrucosa). dri...          79.99
#
#                                                     Magnesium (mg/d)  \
# Miso soup. dehydrated. reconstituted                            2.30
# Lamb's lettuce. raw                                            24.85
# Spinach. young leaves. raw                                      4.23
# Gnocchi. cooked (average)                                      39.14
# Liver. calf. cooked                                             0.10
# Liver. turkey. raw                                              4.74
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                      1.81
# Anchovy. fillets. in oil. semi-preserved. drained               0.53
# Wheat germ oil                                                  0.00
# Walnut oil                                                      0.00
# Grapeseed oil                                                   0.00
# Cod liver oil                                                   0.00
# Parsley. fresh                                                  5.02
# Sea lettuce (ulva sp.). dried or dehydrated)                   16.87
# Gracilaria seaweeds (Gracilaria verrucosa). dri...              0.39
#
#                                                     Manganese (mg/d)  \
# Miso soup. dehydrated. reconstituted                            3.12
# Lamb's lettuce. raw                                            42.72
# Spinach. young leaves. raw                                      6.96
# Gnocchi. cooked (average)                                       0.00
# Liver. calf. cooked                                             0.16
# Liver. turkey. raw                                              6.92
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                      0.67
# Anchovy. fillets. in oil. semi-preserved. drained               0.14
# Wheat germ oil                                                  0.00
# Walnut oil                                                      0.00
# Grapeseed oil                                                   0.02
# Cod liver oil                                                   0.00
# Parsley. fresh                                                 25.20
# Sea lettuce (ulva sp.). dried or dehydrated)                    2.74
# Gracilaria seaweeds (Gracilaria verrucosa). dri...             11.35
#
#                                                     Phosphorus (mg/d)  \
# Miso soup. dehydrated. reconstituted                             3.91
# Lamb's lettuce. raw                                             24.19
# Spinach. young leaves. raw                                       1.90
# Gnocchi. cooked (average)                                        0.00
# Liver. calf. cooked                                              0.89
# Liver. turkey. raw                                              34.00
# Dry-cured ham. fat and rind removed                             20.61
# Horse mackerel. oily (autumn. winter). raw                       6.88
# Anchovy. fillets. in oil. semi-preserved. drained                1.74
# Wheat germ oil                                                   0.00
# Walnut oil                                                       0.00
# Grapeseed oil                                                    0.00
# Cod liver oil                                                    0.00
# Parsley. fresh                                                   5.09
# Sea lettuce (ulva sp.). dried or dehydrated)                     0.68
# Gracilaria seaweeds (Gracilaria verrucosa). dri...               0.10
#
#                                                     Potassium (mg/d)  \
# Miso soup. dehydrated. reconstituted                            1.59
# Lamb's lettuce. raw                                            41.86
# Spinach. young leaves. raw                                      5.41
# Gnocchi. cooked (average)                                      35.29
# Liver. calf. cooked                                             0.16
# Liver. turkey. raw                                              4.10
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                      2.12
# Anchovy. fillets. in oil. semi-preserved. drained               0.42
# Wheat germ oil                                                  0.00
# Walnut oil                                                      0.00
# Grapeseed oil                                                   0.00
# Cod liver oil                                                   0.00
# Parsley. fresh                                                  7.37
# Sea lettuce (ulva sp.). dried or dehydrated)                    1.15
# Gracilaria seaweeds (Gracilaria verrucosa). dri...              0.53
#
#                                                     Selenium (µg/d)  \
# Miso soup. dehydrated. reconstituted                          17.56
# Lamb's lettuce. raw                                           68.76
# Spinach. young leaves. raw                                     5.06
# Gnocchi. cooked (average)                                      0.00
# Liver. calf. cooked                                            0.51
# Liver. turkey. raw                                             0.00
# Dry-cured ham. fat and rind removed                            0.00
# Horse mackerel. oily (autumn. winter). raw                     6.44
# Anchovy. fillets. in oil. semi-preserved. drained              0.26
# Wheat germ oil                                                 0.00
# Walnut oil                                                     0.24
# Grapeseed oil                                                  0.88
# Cod liver oil                                                  0.00
# Parsley. fresh                                                 0.03
# Sea lettuce (ulva sp.). dried or dehydrated)                   0.24
# Gracilaria seaweeds (Gracilaria verrucosa). dri...             0.02
#
#                                                     Sodium (mg/d)  \
# Miso soup. dehydrated. reconstituted                         9.64
# Lamb's lettuce. raw                                          0.43
# Spinach. young leaves. raw                                   0.16
# Gnocchi. cooked (average)                                   59.93
# Liver. calf. cooked                                          0.03
# Liver. turkey. raw                                           1.71
# Dry-cured ham. fat and rind removed                         23.08
# Horse mackerel. oily (autumn. winter). raw                   0.21
# Anchovy. fillets. in oil. semi-preserved. drained            3.38
# Wheat germ oil                                               0.00
# Walnut oil                                                   0.00
# Grapeseed oil                                                0.01
# Cod liver oil                                                0.00
# Parsley. fresh                                               0.45
# Sea lettuce (ulva sp.). dried or dehydrated)                 0.79
# Gracilaria seaweeds (Gracilaria verrucosa). dri...           0.19
#
#                                                     Zinc (mg/d)  \
# Miso soup. dehydrated. reconstituted                       1.24
# Lamb's lettuce. raw                                        6.16
# Spinach. young leaves. raw                                 1.39
# Gnocchi. cooked (average)                                 61.96
# Liver. calf. cooked                                        0.74
# Liver. turkey. raw                                        22.40
# Dry-cured ham. fat and rind removed                        0.00
# Horse mackerel. oily (autumn. winter). raw                 0.73
# Anchovy. fillets. in oil. semi-preserved. drained          1.20
# Wheat germ oil                                             0.00
# Walnut oil                                                 0.00
# Grapeseed oil                                              0.03
# Cod liver oil                                              0.01
# Parsley. fresh                                             3.29
# Sea lettuce (ulva sp.). dried or dehydrated)               0.75
# Gracilaria seaweeds (Gracilaria verrucosa). dri...         0.10
#
#                                                     Vitamin D (µg/d)  \
# Miso soup. dehydrated. reconstituted                            1.95
# Lamb's lettuce. raw                                             0.00
# Spinach. young leaves. raw                                      0.56
# Gnocchi. cooked (average)                                       0.00
# Liver. calf. cooked                                             0.28
# Liver. turkey. raw                                              5.99
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                     64.79
# Anchovy. fillets. in oil. semi-preserved. drained               0.48
# Wheat germ oil                                                  0.00
# Walnut oil                                                      0.00
# Grapeseed oil                                                   0.10
# Cod liver oil                                                  25.66
# Parsley. fresh                                                  0.00
# Sea lettuce (ulva sp.). dried or dehydrated)                    0.19
# Gracilaria seaweeds (Gracilaria verrucosa). dri...              0.00
#
#                                                     Vitamin E (mg/d)  \
# Miso soup. dehydrated. reconstituted                            2.34
# Lamb's lettuce. raw                                             7.75
# Spinach. young leaves. raw                                      1.45
# Gnocchi. cooked (average)                                       0.00
# Liver. calf. cooked                                             0.08
# Liver. turkey. raw                                              1.28
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                      0.74
# Anchovy. fillets. in oil. semi-preserved. drained               0.38
# Wheat germ oil                                                 68.23
# Walnut oil                                                      0.90
# Grapeseed oil                                                   7.07
# Cod liver oil                                                   3.55
# Parsley. fresh                                                  5.92
# Sea lettuce (ulva sp.). dried or dehydrated)                    0.32
# Gracilaria seaweeds (Gracilaria verrucosa). dri...              0.00
#
#                                                     Vitamin K1 (µg/d)  \
# Miso soup. dehydrated. reconstituted                             0.17
# Lamb's lettuce. raw                                             27.73
# Spinach. young leaves. raw                                       3.15
# Gnocchi. cooked (average)                                        0.00
# Liver. calf. cooked                                              0.00
# Liver. turkey. raw                                               0.00
# Dry-cured ham. fat and rind removed                              0.00
# Horse mackerel. oily (autumn. winter). raw                       0.00
# Anchovy. fillets. in oil. semi-preserved. drained                0.06
# Wheat germ oil                                                   0.18
# Walnut oil                                                       0.12
# Grapeseed oil                                                    1.37
# Cod liver oil                                                    0.00
# Parsley. fresh                                                  67.22
# Sea lettuce (ulva sp.). dried or dehydrated)                     0.00
# Gracilaria seaweeds (Gracilaria verrucosa). dri...               0.00
#
#                                                     Vitamin C (mg/d)  \
# Miso soup. dehydrated. reconstituted                            0.00
# Lamb's lettuce. raw                                             9.90
# Spinach. young leaves. raw                                      1.85
# Gnocchi. cooked (average)                                       0.00
# Liver. calf. cooked                                             0.20
# Liver. turkey. raw                                             15.41
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                      0.00
# Anchovy. fillets. in oil. semi-preserved. drained               0.02
# Wheat germ oil                                                  0.00
# Walnut oil                                                      0.00
# Grapeseed oil                                                   0.00
# Cod liver oil                                                   0.00
# Parsley. fresh                                                 71.57
# Sea lettuce (ulva sp.). dried or dehydrated)                    1.05
# Gracilaria seaweeds (Gracilaria verrucosa). dri...              0.00
#
#                                                     Vitamin B1 or Thiamin (mg/d)  \
# Miso soup. dehydrated. reconstituted                                        1.68
# Lamb's lettuce. raw                                                        18.37
# Spinach. young leaves. raw                                                  1.32
# Gnocchi. cooked (average)                                                   0.00
# Liver. calf. cooked                                                         0.24
# Liver. turkey. raw                                                         13.88
# Dry-cured ham. fat and rind removed                                        58.31
# Horse mackerel. oily (autumn. winter). raw                                  1.53
# Anchovy. fillets. in oil. semi-preserved. drained                           0.16
# Wheat germ oil                                                              0.00
# Walnut oil                                                                  0.00
# Grapeseed oil                                                               0.00
# Cod liver oil                                                               0.00
# Parsley. fresh                                                              4.25
# Sea lettuce (ulva sp.). dried or dehydrated)                                0.26
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                          0.00
#
#                                                     Vitamin B2 or Riboflavin (mg/d)  \
# Miso soup. dehydrated. reconstituted                                           0.53
# Lamb's lettuce. raw                                                           13.73
# Spinach. young leaves. raw                                                     0.87
# Gnocchi. cooked (average)                                                      0.00
# Liver. calf. cooked                                                            1.31
# Liver. turkey. raw                                                            70.75
# Dry-cured ham. fat and rind removed                                            6.94
# Horse mackerel. oily (autumn. winter). raw                                     1.09
# Anchovy. fillets. in oil. semi-preserved. drained                              0.48
# Wheat germ oil                                                                 0.00
# Walnut oil                                                                     0.00
# Grapeseed oil                                                                  0.00
# Cod liver oil                                                                  0.00
# Parsley. fresh                                                                 4.04
# Sea lettuce (ulva sp.). dried or dehydrated)                                   0.24
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                             0.00
#
#                                                     Vitamin B3 or Niacin (mg/d)  \
# Miso soup. dehydrated. reconstituted                                       0.70
# Lamb's lettuce. raw                                                       10.11
# Spinach. young leaves. raw                                                 0.52
# Gnocchi. cooked (average)                                                  0.00
# Liver. calf. cooked                                                        1.88
# Liver. turkey. raw                                                        46.26
# Dry-cured ham. fat and rind removed                                       26.42
# Horse mackerel. oily (autumn. winter). raw                                 8.02
# Anchovy. fillets. in oil. semi-preserved. drained                          0.99
# Wheat germ oil                                                             0.00
# Walnut oil                                                                 0.00
# Grapeseed oil                                                              0.00
# Cod liver oil                                                              0.00
# Parsley. fresh                                                             4.01
# Sea lettuce (ulva sp.). dried or dehydrated)                               1.09
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                         0.00
#
#                                                     Vitamin B5 or Pantothenic acid (mg/d)  \
# Miso soup. dehydrated. reconstituted                                                 1.35
# Lamb's lettuce. raw                                                                 19.37
# Spinach. young leaves. raw                                                           1.14
# Gnocchi. cooked (average)                                                            0.00
# Liver. calf. cooked                                                                  0.51
# Liver. turkey. raw                                                                  73.51
# Dry-cured ham. fat and rind removed                                                  0.00
# Horse mackerel. oily (autumn. winter). raw                                           0.98
# Anchovy. fillets. in oil. semi-preserved. drained                                    0.45
# Wheat germ oil                                                                       0.00
# Walnut oil                                                                           0.00
# Grapeseed oil                                                                        0.00
# Cod liver oil                                                                        0.00
# Parsley. fresh                                                                       2.63
# Sea lettuce (ulva sp.). dried or dehydrated)                                         0.05
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                                   0.00
#
#                                                     Vitamin B6 (mg/d)  \
# Miso soup. dehydrated. reconstituted                             0.69
# Lamb's lettuce. raw                                             25.85
# Spinach. young leaves. raw                                       2.97
# Gnocchi. cooked (average)                                        0.00
# Liver. calf. cooked                                              1.01
# Liver. turkey. raw                                              42.32
# Dry-cured ham. fat and rind removed                             17.95
# Horse mackerel. oily (autumn. winter). raw                       4.36
# Anchovy. fillets. in oil. semi-preserved. drained                0.93
# Wheat germ oil                                                   0.00
# Walnut oil                                                       0.00
# Grapeseed oil                                                    0.00
# Cod liver oil                                                    0.00
# Parsley. fresh                                                   3.92
# Sea lettuce (ulva sp.). dried or dehydrated)                     0.00
# Gracilaria seaweeds (Gracilaria verrucosa). dri...               0.00
#
#                                                     Vitamin B9 or Folate (µg/d)  \
# Miso soup. dehydrated. reconstituted                                       2.43
# Lamb's lettuce. raw                                                       26.25
# Spinach. young leaves. raw                                                 3.34
# Gnocchi. cooked (average)                                                  0.00
# Liver. calf. cooked                                                        1.25
# Liver. turkey. raw                                                        59.01
# Dry-cured ham. fat and rind removed                                        0.00
# Horse mackerel. oily (autumn. winter). raw                                 0.00
# Anchovy. fillets. in oil. semi-preserved. drained                          0.08
# Wheat germ oil                                                             0.00
# Walnut oil                                                                 0.00
# Grapeseed oil                                                              0.00
# Cod liver oil                                                              0.00
# Parsley. fresh                                                             7.51
# Sea lettuce (ulva sp.). dried or dehydrated)                               0.14
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                         0.00
#
#                                                     Vitamin B12 (µg/d)  \
# Miso soup. dehydrated. reconstituted                             11.77
# Lamb's lettuce. raw                                               0.00
# Spinach. young leaves. raw                                        0.00
# Gnocchi. cooked (average)                                         0.00
# Liver. calf. cooked                                               4.47
# Liver. turkey. raw                                               69.27
# Dry-cured ham. fat and rind removed                               1.29
# Horse mackerel. oily (autumn. winter). raw                        7.64
# Anchovy. fillets. in oil. semi-preserved. drained                 4.53
# Wheat germ oil                                                    0.00
# Walnut oil                                                        0.00
# Grapeseed oil                                                     0.00
# Cod liver oil                                                     0.00
# Parsley. fresh                                                    0.00
# Sea lettuce (ulva sp.). dried or dehydrated)                      1.03
# Gracilaria seaweeds (Gracilaria verrucosa). dri...                0.00
#
#                                                     Vitamin A (µg/d)
# Miso soup. dehydrated. reconstituted                            0.00
# Lamb's lettuce. raw                                            27.03
# Spinach. young leaves. raw                                      1.70
# Gnocchi. cooked (average)                                       0.00
# Liver. calf. cooked                                             1.90
# Liver. turkey. raw                                             60.27
# Dry-cured ham. fat and rind removed                             0.00
# Horse mackerel. oily (autumn. winter). raw                      0.01
# Anchovy. fillets. in oil. semi-preserved. drained               0.00
# Wheat germ oil                                                  0.00
# Walnut oil                                                      0.00
# Grapeseed oil                                                   0.00
# Cod liver oil                                                   4.99
# Parsley. fresh                                                  4.05
# Sea lettuce (ulva sp.). dried or dehydrated)                    0.04
# Gracilaria seaweeds (Gracilaria verrucosa). dri...              0.00

# %%
activities = solver2.ComputeConstraintActivities()
o = [{'Name':c.name(), 'shadow price':c.dual_value(), 'slack': (activities[i] - c.lb())} for i, c in enumerate(solver2.constraints())]
df_sensitivity = pd.DataFrame(o)
print(df_sensitivity.round(2))
# Out:
#                                      Name  shadow price    slack
# 0                         Energy (kcal/d)          0.00  1986.08
# 1                           Protein (g/d)          3.50    -0.00
# 2                      Carbohydrate (g/d)          2.61    -0.00
# 3                               Fat (g/d)          8.55    -0.00
# 4                            Fibres (g/d)          1.22    -0.00
# 5                                LA (g/d)          0.69     0.00
# 6                               ALA (g/d)          0.55    -0.00
# 7                               EPA (g/d)          0.00     0.15
# 8                               DHA (g/d)          0.00     0.31
# 9                          Calcium (mg/d)          0.00   149.88
# 10                        Chloride (mg/d)          0.00     0.00
# 11                          Copper (mg/d)          0.16     0.00
# 12                            Iron (mg/d)          0.00     8.80
# 13                          Iodine (µg/d)          0.00  1871.79
# 14                       Magnesium (mg/d)          0.02     0.00
# 15                       Manganese (mg/d)          0.54    -0.00
# 16                      Phosphorus (mg/d)          0.00    17.60
# 17                       Potassium (mg/d)          0.00   108.33
# 18                        Selenium (µg/d)          0.00    63.14
# 19                          Sodium (mg/d)          0.00  3311.28
# 20                            Zinc (mg/d)          0.00     0.40
# 21                       Vitamin D (µg/d)          0.16     0.00
# 22                       Vitamin E (mg/d)          0.07    -0.00
# 23                      Vitamin K1 (µg/d)          0.00   737.25
# 24                       Vitamin C (mg/d)          0.03    -0.00
# 25           Vitamin B1 or Thiamin (mg/d)          4.87     0.00
# 26        Vitamin B2 or Riboflavin (mg/d)          0.00     0.60
# 27            Vitamin B3 or Niacin (mg/d)          0.38     0.00
# 28  Vitamin B5 or Pantothenic acid (mg/d)          0.00     0.91
# 29                      Vitamin B6 (mg/d)          3.94     0.00
# 30            Vitamin B9 or Folate (µg/d)          0.00   463.53
# 31                     Vitamin B12 (µg/d)          0.00    15.67
# 32                       Vitamin A (µg/d)          0.00  8505.63

# %% [markdown]
# The constraints with a slack value of zero are the most critical for the solution.
# It these constraints are changed the solution will also change.
# There are much more critical constraint for the calories optimized diet than for the weight optimized diet.
# The higher the shadow price the more sensitive is the objective function to changes of that constraint.
# So the most critical constraints are

# %%
df_sensitivity.sort_values("shadow price", ascending=False).loc[df_sensitivity["slack"].round(2) == 0.0].round(2)
# Out:
#                             Name  shadow price  slack
# 3                      Fat (g/d)          8.55   -0.0
# 25  Vitamin B1 or Thiamin (mg/d)          4.87    0.0
# 29             Vitamin B6 (mg/d)          3.94    0.0
# 1                  Protein (g/d)          3.50   -0.0
# 2             Carbohydrate (g/d)          2.61   -0.0
# 4                   Fibres (g/d)          1.22   -0.0
# 5                       LA (g/d)          0.69    0.0
# 6                      ALA (g/d)          0.55   -0.0
# 15              Manganese (mg/d)          0.54   -0.0
# 27   Vitamin B3 or Niacin (mg/d)          0.38    0.0
# 21              Vitamin D (µg/d)          0.16    0.0
# 11                 Copper (mg/d)          0.16    0.0
# 22              Vitamin E (mg/d)          0.07   -0.0
# 24              Vitamin C (mg/d)          0.03   -0.0
# 14              Magnesium (mg/d)          0.02    0.0
# 10               Chloride (mg/d)          0.00    0.0
